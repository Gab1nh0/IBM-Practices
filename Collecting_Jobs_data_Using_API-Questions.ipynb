# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Collecting Job Data Using APIs**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab, you will be able to:

# %% [markdown]
# *   Collect job data from Jobs API
# *   Store the collected data into an excel spreadsheet.

# %% [markdown]
# ><strong>Note: Before starting with the assignment make sure to read all the instructions and then move ahead with the coding part.</strong>

# %% [markdown]
# #### Instructions

# %% [markdown]
# To run the actual lab, firstly you need to click on the [Jobs_API](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/Jobs_API.ipynb) notebook link. The file contains flask code which is required to run the Jobs API data.
#
# Now, to run the code in the file that opens up follow the below steps.
#
# Step1: Download the file.
#
# Step2: Upload it on the IBM Watson studio. (If IBM Watson Cloud service does not work in your system, follow the alternate Step 2 below)
#
# Step2(alternate): Upload it in your SN labs environment using the upload button which is highlighted in red in the image below:
# Remember to upload this Jobs_API file in the same folder as your current .ipynb file
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/Upload.PNG">
#
# Step3:  Run all the cells of the Jobs_API file. (Even if you receive an asterik sign after running the last cell, the code works fine.)
#
# If you want to learn more about flask, which is optional, you can click on this link [here](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/FLASK_API.md.html).
#
# Once you run the flask code, you can start with your assignment.

# %% [markdown]
# ## Dataset Used in this Assignment
#
# The dataset used in this lab comes from the following source: https://www.kaggle.com/promptcloud/jobs-on-naukricom under the under a **Public Domain license**.
#
# > Note: We are using a modified subset of that dataset for the lab, so to follow the lab instructions successfully please use the dataset provided with the lab, rather than the dataset from the original source.
#
# The original dataset is a csv. We have converted the csv to json as per the requirement of the lab.

# %% [markdown]
# ## Warm-Up Exercise

# %% [markdown]
# Before you attempt the actual lab, here is a fully solved warmup exercise that will help you to learn how to access an API.

# %% [markdown]
# Using an API, let us find out who currently are on the International Space Station (ISS).<br> The API at [http://api.open-notify.org/astros.json](http://api.open-notify.org/astros.json?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2021-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ) gives us the information of astronauts currently on ISS in json format.<br>
# You can read more about this API at [http://open-notify.org/Open-Notify-API/People-In-Space/](http://open-notify.org/Open-Notify-API/People-In-Space?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2021-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)

# %%
import requests # you need this module to make an API call
import pandas as pd

# %%
api_url = "http://api.open-notify.org/astros.json" # this url gives use the astronaut data

# %%
response = requests.get(api_url) # Call the API using the get method and store the
                                # output of the API call in a variable called response.

# %%
if response.ok:             # if all is well() no errors, no network timeouts)
    data = response.json()  # store the result in json format in a variable called data
                            # the variable data is of type dictionary.

# %%
print(data)   # print the data just to check the output or for debugging
# Out:
# {'people': [{'craft': 'ISS', 'name': 'Oleg Kononenko'}, {'craft': 'ISS', 'name': 'Nikolai Chub'}, {'craft': 'ISS', 'name': 'Tracy Caldwell Dyson'}, {'craft': 'ISS', 'name': 'Matthew Dominick'}, {'craft': 'ISS', 'name': 'Michael Barratt'}, {'craft': 'ISS', 'name': 'Jeanette Epps'}, {'craft': 'ISS', 'name': 'Alexander Grebenkin'}, {'craft': 'ISS', 'name': 'Butch Wilmore'}, {'craft': 'ISS', 'name': 'Sunita Williams'}, {'craft': 'Tiangong', 'name': 'Li Guangsu'}, {'craft': 'Tiangong', 'name': 'Li Cong'}, {'craft': 'Tiangong', 'name': 'Ye Guangfu'}], 'number': 12, 'message': 'success'}

# %% [markdown]
# Print the number of astronauts currently on ISS.

# %%
print(data.get('number'))
# Out:
# 12

# %% [markdown]
# Print the names of the astronauts currently on ISS.

# %%
astronauts = data.get('people')
print("There are {} astronauts on ISS".format(len(astronauts)))
print("And their names are :")
for astronaut in astronauts:
    print(astronaut.get('name'))
# Out:
# There are 12 astronauts on ISS
# And their names are :
# Oleg Kononenko
# Nikolai Chub
# Tracy Caldwell Dyson
# Matthew Dominick
# Michael Barratt
# Jeanette Epps
# Alexander Grebenkin
# Butch Wilmore
# Sunita Williams
# Li Guangsu
# Li Cong
# Ye Guangfu

# %% [markdown]
# Hope the warmup was helpful. Good luck with your next lab!

# %% [markdown]
# ## Lab: Collect Jobs Data using Jobs API

# %% [markdown]
# ### Objective: Determine the number of jobs currently open for various technologies  and for various locations

# %% [markdown]
# Collect the number of job postings for the following locations using the API:
#
# * Los Angeles
# * New York
# * San Francisco
# * Washington DC
# * Seattle
# * Austin
# * Detroit

# %%
#Import required libraries
import pandas as pd
import json

# %% [markdown]
# #### Write a function to get the number of jobs for the Python technology.<br>
# > Note: While using the lab you need to pass the **payload** information for the **params** attribute in the form of **key** **value** pairs.
#   Refer the ungraded **rest api lab** in the course **Python for Data Science, AI & Development**  <a href="https://www.coursera.org/learn/python-for-applied-data-science-ai/ungradedLti/P6sW8/hands-on-lab-access-rest-apis-request-http?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01">link</a>
#
#  ##### The keys in the json are
#  * Job Title
#
#  * Job Experience Required
#
#  * Key Skills
#
#  * Role Category
#
#  * Location
#
#  * Functional Area
#
#  * Industry
#
#  * Role
#
# You can also view  the json file contents  from the following <a href = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/jobs.json">json</a> URL.

# %%
api_url="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/jobs.json"

response = requests.get(api_url)
    
if response.ok:             
    data = response.json()

# %%
for job in data:
    job_technology = job['Key Skills']

cuenta = len(job_technology)
# Out:
# 156

# %%
def get_number_of_jobs_T(technology):
    number_of_jobs = 0
    
    for job in data:
        
        job_skills = job['Key Skills'].split('|')
        
        
        if any(technology.lower() in skill.lower() for skill in job_skills):
            number_of_jobs += 1
    
    return technology, number_of_jobs

# %% [markdown]
# Calling the function for Python and checking if it works.

# %%
get_number_of_jobs_T("Python")
# Out:
# ('Python', 1173)

# %% [markdown]
# #### Write a function to find number of jobs in US for a location of your choice

# %%
jobs = {}  # Diccionario para almacenar trabajos según la ubicación

def get_number_of_jobs_L(location):
    # Diccionario vacío para almacenar trabajos que coinciden con la ubicación
    jobs_by_location = {}
    
    # Iteramos sobre los trabajos
    for i, job in enumerate(data):
        job_location = job['Location']
        job_title = job['Job Title']
        
        # Si la ubicación coincide, añadimos el trabajo al diccionario
        if location.lower() == job_location.lower():
            jobs_by_location[i] = {'title': job_title, 'location': job_location}
    
    return jobs_by_location

# %% [markdown]
# Call the function for Los Angeles and check if it is working.

# %%
get_number_of_jobs_L('Los Angeles')
# Out:
# {0: {'title': 'Digital Media Planner', 'location': 'Los Angeles'},
#  10: {'title': 'Executive Assistant To Chairman', 'location': 'Los Angeles'},
#  79: {'title': 'Manager (Service Operation)', 'location': 'Los Angeles'},
#  80: {'title': 'DevOps Engineer Intern', 'location': 'Los Angeles'},
#  81: {'title': 'PHP Developer (wordpress & Woo Commerce/shopify / Magento)',
#   'location': 'Los Angeles'},
#  82: {'title': 'Java Developer', 'location': 'Los Angeles'},
#  83: {'title': 'Sr. Manager- Business Development', 'location': 'Los Angeles'},
#  84: {'title': 'Test Principal Engineer', 'location': 'Los Angeles'},
#  85: {'title': 'Graphic Designer', 'location': 'Los Angeles'},
#  86: {'title': 'Business Development Executive', 'location': 'Los Angeles'},
#  87: {'title': 'Animation Resident', 'location': 'Los Angeles'},
#  88: {'title': 'Enterprise Business Development Representative',
#   'location': 'Los Angeles'},
#  89: {'title': 'Dot Net Developer', 'location': 'Los Angeles'},
#  90: {'title': 'Urgent Opening for "US Staffing Professionals" - New York',
#   'location': 'Los Angeles'},
#  91: {'title': 'Project Executive/coordinator', 'location': 'Los Angeles'},
#  92: {'title': 'Sterling OMS Architect', 'location': 'Los Angeles'},
#  93: {'title': 'Dot net Developer', 'location': 'Los Angeles'},
#  94: {'title': 'Centreless Grinding Operator', 'location': 'Los Angeles'},
#  95: {'title': 'PHP Developer Jobs In Florida - Team Lead - PHP',
#   'location': 'Los Angeles'},
#  96: {'title': 'Sales Lead', 'location': 'Los Angeles'},
#  97: {'title': 'Senior Design Engineer - Manufacturing',
#   'location': 'Los Angeles'},
#  98: {'title': 'Software Engineer Automation - Industrial Automation Job In Bangalore',
#   'location': 'Los Angeles'},
#  99: {'title': 'Looking For Assistant Manager - Healthcare (US Visa is Must)',
#   'location': 'Los Angeles'},
#  100: {'title': 'QA for Voice Process (LE-0097-N1C)',
#   'location': 'Los Angeles'},
#  101: {'title': 'Manager/senior Manager- Analytics- Life & Annuities - Insurance Domain',
#   'location': 'Los Angeles'},
#  102: {'title': 'Executive Medical Coder', 'location': 'Los Angeles'},
#  103: {'title': 'Account Assistant', 'location': 'Los Angeles'},
#  104: {'title': 'Informatica Faculty Job Requirement in Hyderabad',
#   'location': 'Los Angeles'},
#  105: {'title': 'SEO Expert/ Digital Marketing Florida',
#   'location': 'Los Angeles'},
#  106: {'title': 'Head Engineering', 'location': 'Los Angeles'},
#  107: {'title': 'Business Development Executive', 'location': 'Los Angeles'},
#  108: {'title': 'PPC Executive', 'location': 'Los Angeles'},
#  109: {'title': 'Opening For the post of Mr/territory Business Manager in An Pharma',
#   'location': 'Los Angeles'},
#  110: {'title': 'Deputy Manager - Program Management',
#   'location': 'Los Angeles'},
#  111: {'title': 'Public Relations Manager - Bangalore',
#   'location': 'Los Angeles'},
#  112: {'title': "Female Fresher's Counsellor- Florida",
#   'location': 'Los Angeles'},
#  113: {'title': 'BE Chemical - Fresher', 'location': 'Los Angeles'},
#  114: {'title': 'Senior .Net Developer For Leading IT Company in Florida',
#   'location': 'Los Angeles'},
#  115: {'title': 'Hiring a Valuation Associate (female Only)',
#   'location': 'Los Angeles'},
#  116: {'title': 'Merchandising & Marketing- Professor',
#   'location': 'Los Angeles'},
#  117: {'title': 'Medical Transcriber', 'location': 'Los Angeles'},
#  118: {'title': 'PHP Developer', 'location': 'Los Angeles'},
#  119: {'title': 'Business Development Manager', 'location': 'Los Angeles'},
#  120: {'title': 'Looking for a Job Change With a good package',
#   'location': 'Los Angeles'},
#  121: {'title': 'Huge Requirement for Customer Care Executive with Fixed Salary',
#   'location': 'Los Angeles'},
#  122: {'title': 'Assistant Manager – BI&I (data Automation)',
#   'location': 'Los Angeles'},
#  123: {'title': 'Field Sales Executive', 'location': 'Los Angeles'},
#  124: {'title': 'Sr. Manager Sales Capability Building',
#   'location': 'Los Angeles'},
#  125: {'title': 'Service Ops Expert - Servc Del | Microland',
#   'location': 'Los Angeles'},
#  126: {'title': 'Regional Trainer - Skin for Wellness & Beauty Industry (only Females)',
#   'location': 'Los Angeles'},
#  127: {'title': 'Sales Manager', 'location': 'Los Angeles'},
#  128: {'title': 'Field Support Team-Supervisor', 'location': 'Los Angeles'},
#  129: {'title': 'Sr. C# Developer', 'location': 'Los Angeles'},
#  130: {'title': 'Sr Structural Engineer', 'location': 'Los Angeles'},
#  131: {'title': 'IT Security Head', 'location': 'Los Angeles'},
#  132: {'title': 'Technical Support Executive', 'location': 'Los Angeles'},
#  133: {'title': 'Analyst - Business Intelligence', 'location': 'Los Angeles'},
#  134: {'title': 'Nokia WING Circuit Core - SMSC Engineer',
#   'location': 'Los Angeles'},
#  135: {'title': 'Assistant Restaurant Manager / Restaurant Manager',
#   'location': 'Los Angeles'},
#  136: {'title': 'Digital / Web Artist', 'location': 'Los Angeles'},
#  137: {'title': 'Business Development Manager', 'location': 'Los Angeles'},
#  138: {'title': 'Web/ GUI Designer', 'location': 'Los Angeles'},
#  139: {'title': 'Web Designer - Html, CSS, Bootstrap, Photoshop',
#   'location': 'Los Angeles'},
#  140: {'title': 'Python Developer', 'location': 'Los Angeles'},
#  141: {'title': 'Web Designer', 'location': 'Los Angeles'},
#  142: {'title': 'AVP- FX MO', 'location': 'Los Angeles'},
#  143: {'title': 'Cluster Sales Head - Tied Channel &amp; Affinity Alliances - Health Insura',
#   'location': 'Los Angeles'},
#  144: {'title': 'Head - Project Management', 'location': 'Los Angeles'},
#  145: {'title': 'Walk- In For Development QA/ Regulatory Affairs',
#   'location': 'Los Angeles'},
#  146: {'title': 'Manager Accounts-wazirpur-mba-finance-salary-35k(export House exp)',
#   'location': 'Los Angeles'},
#  147: {'title': 'Team Leader- Head Digital Prtnrshp & BD',
#   'location': 'Los Angeles'},
#  148: {'title': 'DWH Tester - Manual Testing', 'location': 'Los Angeles'},
#  149: {'title': 'Quality Assurance Engineer', 'location': 'Los Angeles'},
#  150: {'title': 'Technical / Functional Skills', 'location': 'Los Angeles'},
#  151: {'title': 'Software Development / Software Engineer',
#   'location': 'Los Angeles'},
#  152: {'title': 'Inbound Phone Banking Voice Process - Leading Bank - New York',
#   'location': 'Los Angeles'},
#  153: {'title': 'Java Enterprise Edition', 'location': 'Los Angeles'},
#  154: {'title': 'Associate Clinical Data Processor',
#   'location': 'Los Angeles'},
#  155: {'title': 'CRM', 'location': 'Los Angeles'},
#  156: {'title': 'Magento Developer', 'location': 'Los Angeles'},
#  157: {'title': 'Merchandiser', 'location': 'Los Angeles'},
#  158: {'title': 'Hiring ll Azure Devops and Management Lead ll Hyderabad',
#   'location': 'Los Angeles'},
#  159: {'title': 'Operation Executive', 'location': 'Los Angeles'},
#  160: {'title': 'Customer Support Executive', 'location': 'Los Angeles'},
#  161: {'title': 'Corporate-Day Care Manager.', 'location': 'Los Angeles'},
#  162: {'title': 'Hiring going on for .US Inbound Tech Support/ Sales',
#   'location': 'Los Angeles'},
#  163: {'title': 'Deputy Manager- Performance/digital Marketing',
#   'location': 'Los Angeles'},
#  164: {'title': 'Technical Lead -(VoIP,Cisco Call Manager)',
#   'location': 'Los Angeles'},
#  165: {'title': 'Relationship Manager', 'location': 'Los Angeles'},
#  166: {'title': 'Technician, Technical Support', 'location': 'Los Angeles'},
#  167: {'title': 'Graphic Designer', 'location': 'Los Angeles'},
#  168: {'title': 'Consultant', 'location': 'Los Angeles'},
#  169: {'title': 'Immediate Requirement for Fusion Technical Lead Developer',
#   'location': 'Los Angeles'},
#  170: {'title': 'Layout Designer / Web Designer', 'location': 'Los Angeles'},
#  171: {'title': 'International BPO- Mahindra- Meru- TATA SKY- Paddle Point-pepperfry-hc',
#   'location': 'Los Angeles'},
#  172: {'title': 'Asp.net with Angular JS & Html5 - Hyderabad',
#   'location': 'Los Angeles'},
#  173: {'title': 'Sales Manager Product and Portfolio',
#   'location': 'Los Angeles'},
#  174: {'title': 'Key Accounts Manager', 'location': 'Los Angeles'},
#  175: {'title': 'Store Head-leading Manufacturing Company',
#   'location': 'Los Angeles'},
#  176: {'title': 'BPO Inbound Voice Tech Process - Customer Service Inbound Voice - Appl',
#   'location': 'Los Angeles'},
#  177: {'title': 'Java Software Engineer', 'location': 'Los Angeles'},
#  178: {'title': 'Admin Executive', 'location': 'Los Angeles'},
#  179: {'title': 'Agm Finance for Automobile Company in Kolkata . Salary:7 Lpa',
#   'location': 'Los Angeles'},
#  180: {'title': 'Accounts Manager (male)', 'location': 'Los Angeles'},
#  181: {'title': 'Opening for French Specialist Accounts Payable',
#   'location': 'Los Angeles'},
#  182: {'title': 'Applications Analyst OEE', 'location': 'Los Angeles'},
#  183: {'title': 'Customer Service Engineer - - ICD Security Solutions',
#   'location': 'Los Angeles'},
#  184: {'title': 'Urgently Required Senior PHP Developer(laravel) || Florida',
#   'location': 'Los Angeles'},
#  185: {'title': 'Associate Process Consultant', 'location': 'Los Angeles'},
#  186: {'title': 'Infrastructure management- Lecturer',
#   'location': 'Los Angeles'},
#  187: {'title': 'Finance Admin', 'location': 'Los Angeles'},
#  188: {'title': 'Guest Relations Executive', 'location': 'Los Angeles'},
#  189: {'title': 'Salesforce System Architect', 'location': 'Los Angeles'},
#  190: {'title': 'System Monitoring Tools & Techniques Professional',
#   'location': 'Los Angeles'},
#  191: {'title': 'HR Recruiter', 'location': 'Los Angeles'},
#  192: {'title': 'Business Development Manager (eCommerce)',
#   'location': 'Los Angeles'},
#  193: {'title': 'Java Developer - Spring/ Hibernate',
#   'location': 'Los Angeles'},
#  194: {'title': 'Python Developer', 'location': 'Los Angeles'},
#  195: {'title': 'Sales And Marketing/Business Development manager',
#   'location': 'Los Angeles'},
#  196: {'title': 'Microsoft Developer', 'location': 'Los Angeles'},
#  197: {'title': 'Customer Service Executive (Adeeba Group) for Tech Support/ Sales',
#   'location': 'Los Angeles'},
#  198: {'title': 'Inbound Technical Support With Attractive Salary Package',
#   'location': 'Los Angeles'},
#  199: {'title': 'Placement Officer,', 'location': 'Los Angeles'},
#  200: {'title': 'Walk-in Interviews For Sr.executive - Procurement on 5th July',
#   'location': 'Los Angeles'},
#  201: {'title': 'Urgent Opening Automation Test Engineer 2-5yrs-bellandur Bangalore',
#   'location': 'Los Angeles'},
#  202: {'title': 'Senior TSA Inbound Tech Process', 'location': 'Los Angeles'},
#  203: {'title': 'Freelance Corporate Trainer on Taleo',
#   'location': 'Los Angeles'},
#  204: {'title': 'Senior Java Developer- Urgently Required by Arizona IT Company',
#   'location': 'Los Angeles'},
#  205: {'title': 'Manager Procurement', 'location': 'Los Angeles'},
#  206: {'title': 'Senior Software Engineer - UI Development - Javascript/angularjs',
#   'location': 'Los Angeles'},
#  207: {'title': 'Telle Caller', 'location': 'Los Angeles'},
#  208: {'title': 'Restaurant Cashier', 'location': 'Los Angeles'},
#  209: {'title': 'Opening For Dot Net Developer @ Baner, New Jersey',
#   'location': 'Los Angeles'},
#  210: {'title': 'Management Trainee', 'location': 'Los Angeles'},
#  211: {'title': 'Junior Company Secretary', 'location': 'Los Angeles'},
#  212: {'title': 'Production Manager', 'location': 'Los Angeles'},
#  213: {'title': 'Have Confidence to Convince Customer Then Join Adeeba (Inbound Voice)',
#   'location': 'Los Angeles'},
#  214: {'title': 'Content Editor', 'location': 'Los Angeles'},
#  215: {'title': 'Graphics Hardware Engineer', 'location': 'Los Angeles'},
#  216: {'title': 'Visual Designer', 'location': 'Los Angeles'},
#  217: {'title': 'Web Designer', 'location': 'Los Angeles'},
#  218: {'title': 'ACCOUNTS EXECUTIVES', 'location': 'Los Angeles'},
#  219: {'title': 'Finance & Accounting Associates', 'location': 'Los Angeles'},
#  220: {'title': 'DEALER - RETAIL BROKING', 'location': 'Los Angeles'},
#  221: {'title': 'SENIOR SOFTWARE DEVELOPER (MVC .NET)',
#   'location': 'Los Angeles'},
#  222: {'title': 'Client Relationship Partner', 'location': 'Los Angeles'},
#  223: {'title': 'Sales Manger Opening In An E-commerce Industry- (Arizona, New Jersey)',
#   'location': 'Los Angeles'},
#  224: {'title': 'Dot Net Developer', 'location': 'Los Angeles'},
#  225: {'title': 'Sr. Manager- Art in Arizona || Opportunity @ Client side',
#   'location': 'Los Angeles'},
#  226: {'title': 'Hiring for Domestic/ International Processes.contact the HR Asap',
#   'location': 'Los Angeles'},
#  227: {'title': 'Urgent Requirement for CCE Telesales for Night Shift.',
#   'location': 'Los Angeles'},
#  228: {'title': 'Vancancy for Inbound Tech Sales Executive',
#   'location': 'Los Angeles'},
#  229: {'title': 'Infrastructure SSO Architect- Looking For Early Joiners',
#   'location': 'Los Angeles'},
#  230: {'title': 'Sr. Architect / Project Position: Sr. Architect / Project',
#   'location': 'Los Angeles'},
#  231: {'title': 'Nosql (couchdb/redis/bigtable/dynamodb)',
#   'location': 'Los Angeles'},
#  232: {'title': 'Immidate Opening for Voice & Accent Trainer @ Vee Technologies',
#   'location': 'Los Angeles'},
#  233: {'title': 'Walk- in | Hdfc Life | We are Hiring Freshers:5th till 20th Aug@ Ohio',
#   'location': 'Los Angeles'},
#  234: {'title': 'AIT Global India Private Limited is Looking For JAVA Developer.',
#   'location': 'Los Angeles'},
#  235: {'title': 'Cloud Engineer Cloud Based IT MNC In Florida , salary 7 - 8 LPA',
#   'location': 'Los Angeles'},
#  236: {'title': 'Relationship Manager - Bangalore', 'location': 'Los Angeles'},
#  237: {'title': 'Territory Sales Manager-Passive Networking-Arizona/Bangalore/Hyderabad',
#   'location': 'Los Angeles'},
#  238: {'title': 'Business Development Manager', 'location': 'Los Angeles'},
#  239: {'title': 'Senior Manager-fundraising', 'location': 'Los Angeles'},
#  240: {'title': 'Bulk Hiring Travel Sales Consultants US /UK Shifts Call ASAP',
#   'location': 'Los Angeles'},
#  241: {'title': 'UI Developer (Frontend Developer)',
#   'location': 'Los Angeles'},
#  242: {'title': 'Netsuite Technical Consultant', 'location': 'Los Angeles'},
#  243: {'title': 'Java Full Stack – Technical Lead, Senior Engineer',
#   'location': 'Los Angeles'},
#  244: {'title': 'ADM - External Affairs &amp; CSR - Bangalore',
#   'location': 'Los Angeles'},
#  245: {'title': 'Immediate Opening Asp.net MVC Developers For Arizona',
#   'location': 'Los Angeles'},
#  246: {'title': 'Home loan', 'location': 'Los Angeles'},
#  247: {'title': 'Sr. Resident, General & Laparoscopic Surgery',
#   'location': 'Los Angeles'},
#  248: {'title': 'Angular Developer - Fulcrum Digital',
#   'location': 'Los Angeles'},
#  249: {'title': 'Devops Engineer - Tools & Automation',
#   'location': 'Los Angeles'},
#  250: {'title': 'Great Opportunity To join top MNCs in Kolkata! Grab them While it last',
#   'location': 'Los Angeles'},
#  251: {'title': 'QA Functional Testing', 'location': 'Los Angeles'},
#  252: {'title': 'Sales Engineer', 'location': 'Los Angeles'},
#  253: {'title': 'Software Engineer - Unity Developer',
#   'location': 'Los Angeles'},
#  254: {'title': 'Associate Level 1 - Fund Accounting',
#   'location': 'Los Angeles'},
#  255: {'title': 'Associate Principal Analyst - Network Security Research',
#   'location': 'Los Angeles'},
#  256: {'title': 'Urgent Opening For Field Recruiter',
#   'location': 'Los Angeles'},
#  257: {'title': 'JAVA Developer', 'location': 'Los Angeles'},
#  258: {'title': 'Urgent Openings For Pharma Freshers',
#   'location': 'Los Angeles'},
#  259: {'title': 'Front End Developer - Wordpress/html/css/javascript',
#   'location': 'Los Angeles'},
#  260: {'title': 'Mechanical Maintenance – Btech / Diploma',
#   'location': 'Los Angeles'},
#  261: {'title': 'PHP Developer', 'location': 'Los Angeles'},
#  262: {'title': 'Sr.consultant-power Distribution', 'location': 'Los Angeles'},
#  263: {'title': 'Chinese, Spanish Language Expert (proofcheck Medical Content),',
#   'location': 'Los Angeles'},
#  264: {'title': 'Hiring for Tech Sales_Inbound UK/ US Voice Process',
#   'location': 'Los Angeles'},
#  265: {'title': 'SUPPORT Engineers (FEMALE CANDIDATES)',
#   'location': 'Los Angeles'},
#  266: {'title': 'MS SQL Developer : 0 - 2 Years (only MALE Candidates)',
#   'location': 'Los Angeles'},
#  267: {'title': 'Machine Learning Engineer || Florida/chandigarh Location',
#   'location': 'Los Angeles'},
#  268: {'title': 'Nurses', 'location': 'Los Angeles'},
#  269: {'title': 'Marketing Executive', 'location': 'Los Angeles'},
#  270: {'title': 'HR Recruiter (volume Hiring)', 'location': 'Los Angeles'},
#  271: {'title': 'Java Full Stack Developer', 'location': 'Los Angeles'},
#  272: {'title': 'GM Finance- Export Import Company',
#   'location': 'Los Angeles'},
#  273: {'title': 'Content Writer', 'location': 'Los Angeles'},
#  274: {'title': 'Job Opening for Sm/avp_credit Audit_Arizona',
#   'location': 'Los Angeles'},
#  275: {'title': 'iOS Game Developer', 'location': 'Los Angeles'},
#  276: {'title': 'Hiring: Executive-business Developer(seller Acquisition) On Contract',
#   'location': 'Los Angeles'},
#  277: {'title': 'Java/j2ee Application Developer', 'location': 'Los Angeles'},
#  278: {'title': 'Accepting Application for Intership for Java, PHP, Web Design, Android',
#   'location': 'Los Angeles'},
#  279: {'title': 'Automation-Expert-Senior-Automation-Expert',
#   'location': 'Los Angeles'},
#  280: {'title': 'Product Manager- Marketing(consumer Durables)',
#   'location': 'Los Angeles'},
#  281: {'title': 'Embedded Android Engineer', 'location': 'Los Angeles'},
#  282: {'title': 'Inbound International BPO Voice Process-US Shift',
#   'location': 'Los Angeles'},
#  283: {'title': 'Sales Executive', 'location': 'Los Angeles'},
#  293: {'title': 'Mechanical Engineer Require For Shut Down',
#   'location': 'Los Angeles'},
#  296: {'title': 'Technical Support Associate / Technical Sales Associate-Inbound Voice',
#   'location': 'Los Angeles'},
#  306: {'title': 'Software Engineer- Mobile Applications - Android',
#   'location': 'Los Angeles'},
#  309: {'title': 'HR Recruitment Executive', 'location': 'Los Angeles'},
#  319: {'title': 'Senior .NET Developer', 'location': 'Los Angeles'},
#  322: {'title': 'Walk-in Drive for Java Dev/sr. Dev on 29th June at Ohio',
#   'location': 'Los Angeles'},
#  332: {'title': 'Sharepoint Support Engineer', 'location': 'Los Angeles'},
#  335: {'title': 'Hiring For Oracle Apps DBA@ Hyderabad',
#   'location': 'Los Angeles'},
#  345: {'title': 'Senior Game Artist', 'location': 'Los Angeles'},
#  348: {'title': 'PERL Developer', 'location': 'Los Angeles'},
#  358: {'title': 'Senior Data Analyst', 'location': 'Los Angeles'},
#  361: {'title': 'Service Engineer - Bhiwadi', 'location': 'Los Angeles'},
#  371: {'title': 'Sr. Sales / Sales Executive', 'location': 'Los Angeles'},
#  374: {'title': 'Head- Land Management.', 'location': 'Los Angeles'},
#  384: {'title': 'MBA HR - Experience', 'location': 'Los Angeles'},
#  387: {'title': 'Senior Embedded Engineer', 'location': 'Los Angeles'},
#  397: {'title': 'Business Development Manager', 'location': 'Los Angeles'},
#  400: {'title': 'salesfoce Developer +3Years / Arizona',
#   'location': 'Los Angeles'},
#  410: {'title': 'Pre Sales Executive', 'location': 'Los Angeles'},
#  413: {'title': 'Sales Engineers', 'location': 'Los Angeles'},
#  423: {'title': 'React.js Developer', 'location': 'Los Angeles'},
#  426: {'title': 'Urgent Opening - Hp-ux Administrator',
#   'location': 'Los Angeles'},
#  436: {'title': 'MES camster/apriso/hydra engineer',
#   'location': 'Los Angeles'},
#  439: {'title': 'Cognos TM1 Developer (4 6 years)', 'location': 'Los Angeles'},
#  449: {'title': 'Tech caller hiring a huge number of Executives.',
#   'location': 'Los Angeles'},
#  452: {'title': 'Java Developer', 'location': 'Los Angeles'},
#  462: {'title': 'SeSu Specialty Trainer (level 4)', 'location': 'Los Angeles'},
#  465: {'title': 'Senior Implementation/Project Engineer',
#   'location': 'Los Angeles'},
#  475: {'title': 'Assistant Manager _ Medical Reviewer with Accenture',
#   'location': 'Los Angeles'},
#  478: {'title': 'IT - Dean', 'location': 'Los Angeles'},
#  488: {'title': 'Tech Sales', 'location': 'Los Angeles'},
#  491: {'title': 'Operations Head - Integrated Facility Management - West',
#   'location': 'Los Angeles'},
#  501: {'title': 'Opening For Software Tester Experience @ Andheri',
#   'location': 'Los Angeles'},
#  504: {'title': 'Senior Manager-materials Technology Leader',
#   'location': 'Los Angeles'},
#  514: {'title': 'Hiring For Technical Support Officer',
#   'location': 'Los Angeles'},
#  517: {'title': 'Role Designation- Technology Analyst',
#   'location': 'Los Angeles'},
#  527: {'title': 'opportunities in ITES BPO company with experience callers for US S',
#   'location': 'Los Angeles'},
#  530: {'title': 'Immediate Hiring For Inbound Technical Support Rep with 20% Hike',
#   'location': 'Los Angeles'},
#  540: {'title': 'Application support', 'location': 'Los Angeles'},
#  543: {'title': 'Excellent Opp for Bussiness Development Head in Bangalore',
#   'location': 'Los Angeles'},
#  553: {'title': 'ABAP Tech Expert', 'location': 'Los Angeles'},
#  556: {'title': 'Windows Administrator || Bangalore Location || Immediate Start',
#   'location': 'Los Angeles'},
#  566: {'title': 'Director - Business Sales For Cash Mgmt & Payment Solutions Company',
#   'location': 'Los Angeles'},
#  569: {'title': 'Urgently Hiring | Associate/ Sr. Exe- Core Accounting | Day Shift',
#   'location': 'Los Angeles'},
#  579: {'title': 'Hiring For Account Assistant', 'location': 'Los Angeles'},
#  582: {'title': 'Operations Manager', 'location': 'Los Angeles'},
#  592: {'title': 'Business Development Executive', 'location': 'Los Angeles'},
#  595: {'title': 'Front Office Receptionist', 'location': 'Los Angeles'},
#  605: {'title': 'MIS Executive,', 'location': 'Los Angeles'},
#  608: {'title': 'Content Marketing Lead', 'location': 'Los Angeles'},
#  618: {'title': 'UI Developer - React.js & Node.js',
#   'location': 'Los Angeles'},
#  621: {'title': 'OPENING FOR AN EXPERIENCE TESTER @ SEAWOOD',
#   'location': 'Los Angeles'},
#  631: {'title': 'iOS Developer', 'location': 'Los Angeles'},
#  634: {'title': 'Mean Stack/full Stack Web Developer (male)',
#   'location': 'Los Angeles'},
#  644: {'title': 'IOS Developer', 'location': 'Los Angeles'},
#  647: {'title': 'ISE - Team Lead - PCB', 'location': 'Los Angeles'},
#  657: {'title': 'Hiring For Female Football Coach', 'location': 'Los Angeles'},
#  660: {'title': 'Senior Director - Service Engineering | 23499',
#   'location': 'Los Angeles'},
#  670: {'title': 'iPhone/iPad Application developer',
#   'location': 'Los Angeles'},
#  673: {'title': 'Sales Manager', 'location': 'Los Angeles'},
#  683: {'title': 'Business Development Manager', 'location': 'Los Angeles'},
#  686: {'title': 'Executive Sales & Marketing | New Jersey | Aurangabad| Kolhapur | Sangli',
#   'location': 'Los Angeles'},
#  696: {'title': 'Branch Incharge - Gold Loan', 'location': 'Los Angeles'},
#  699: {'title': 'DFT ENGINEERS', 'location': 'Los Angeles'},
#  709: {'title': 'Openings for Medical Process- Upto 34k in hand Excellent Communication',
#   'location': 'Los Angeles'},
#  712: {'title': 'Assistant Manager Marketing (PLA-0548-N1C)',
#   'location': 'Los Angeles'},
#  722: {'title': 'Position title Senior Network Engineer',
#   'location': 'Los Angeles'},
#  725: {'title': 'Technology Lead', 'location': 'Los Angeles'},
#  735: {'title': 'Marketing Executive', 'location': 'Los Angeles'},
#  738: {'title': 'Opening For ETL Testing with Abinitio Experience',
#   'location': 'Los Angeles'},
#  748: {'title': 'SAP SD Analyst Level II', 'location': 'Los Angeles'},
#  751: {'title': 'Microstrategy Developer - Decision Support/business Intelligence',
#   'location': 'Los Angeles'},
#  761: {'title': 'Sr. Product Manager', 'location': 'Los Angeles'},
#  764: {'title': 'F2F Interview on 29th June _ Java Senior Developer / Lead _ Whitefield',
#   'location': 'Los Angeles'},
#  774: {'title': 'Oracle BI Developers Consultant', 'location': 'Los Angeles'},
#  777: {'title': 'F2F Interviews || Lead Recruiter || Florida (july 06)',
#   'location': 'Los Angeles'},
#  787: {'title': 'Clinic Doctor', 'location': 'Los Angeles'},
#  790: {'title': 'Android Developer', 'location': 'Los Angeles'},
#  800: {'title': 'Office Assistant', 'location': 'Los Angeles'},
#  803: {'title': 'Sales & marketing engineer Mal', 'location': 'Los Angeles'},
#  813: {'title': 'DESIGNER KIDS WEAR', 'location': 'Los Angeles'},
#  816: {'title': 'Software Engineer', 'location': 'Los Angeles'},
#  826: {'title': 'Store Manager', 'location': 'Los Angeles'},
#  829: {'title': 'Executive : Gem Portal/govt. Tender',
#   'location': 'Los Angeles'},
#  839: {'title': 'E Commerce Manager in Arizona', 'location': 'Los Angeles'},
#  842: {'title': 'AC Technician Job Openings in Qatar',
#   'location': 'Los Angeles'},
#  852: {'title': 'Technical Lead - Front End Development - Node.js/react.js',
#   'location': 'Los Angeles'},
#  855: {'title': 'Required Data Entry Operator/computer Operator',
#   'location': 'Los Angeles'},
#  865: {'title': 'Residence Engineer -technical Sales - S/9517',
#   'location': 'Los Angeles'},
#  868: {'title': 'area managers sales', 'location': 'Los Angeles'},
#  878: {'title': 'Relationship Manager', 'location': 'Los Angeles'},
#  881: {'title': 'Hexaware Technologies Is Hiring Powershell Developers - Arizona',
#   'location': 'Los Angeles'},
#  891: {'title': 'ASSOCIATE ANALYST / ANALYST', 'location': 'Los Angeles'},
#  894: {'title': 'Java Developer', 'location': 'Los Angeles'},
#  904: {'title': 'IT Recruiter- Urgent Requirement', 'location': 'Los Angeles'},
#  907: {'title': 'Urgent Hiring For " IT Recruiter(Florida)',
#   'location': 'Los Angeles'},
#  917: {'title': '.Net Full Stack Lead, Technology', 'location': 'Los Angeles'},
#  920: {'title': 'Openings for Ipdrg Coders In Chennai and Hyderabad',
#   'location': 'Los Angeles'},
#  930: {'title': 'Software Developer', 'location': 'Los Angeles'},
#  933: {'title': 'OPERATION SUPPORT ASSOCIATE', 'location': 'Los Angeles'},
#  943: {'title': 'US Shift In Adeeba ( INBOUND TECH SUPPORT)',
#   'location': 'Los Angeles'},
#  946: {'title': 'Sales Manager - Agro Equipment', 'location': 'Los Angeles'},
#  956: {'title': 'Hyderabad-Software-Engineer-2', 'location': 'Los Angeles'},
#  959: {'title': 'Technical Sales Coordinator VMAX Plate Beveling MCS. PVT. LTD',
#   'location': 'Los Angeles'},
#  969: {'title': 'Quality Analyst', 'location': 'Los Angeles'},
#  972: {'title': 'Statutory Profile Senior Manager ***close Soon',
#   'location': 'Los Angeles'},
#  982: {'title': 'Digital marketing', 'location': 'Los Angeles'},
#  985: {'title': 'Cafeteria Operations Managers', 'location': 'Los Angeles'},
#  995: {'title': 'Hiring for Outbound Process / bpo / tele Sales/customer Care Executive',
#   'location': 'Los Angeles'},
#  998: {'title': 'Job Description', 'location': 'Los Angeles'},
#  1008: {'title': 'Senior UI Developer - Javascript/html5/css3',
#   'location': 'Los Angeles'},
#  1011: {'title': 'Software Developer', 'location': 'Los Angeles'},
#  1021: {'title': 'Graphic Designer', 'location': 'Los Angeles'},
#  1024: {'title': 'SOCIAL MEDIA MARKETING', 'location': 'Los Angeles'},
#  1034: {'title': 'Production Manager with Production Manager/Supervisor',
#   'location': 'Los Angeles'},
#  1037: {'title': 'VB Programmer:VBP', 'location': 'Los Angeles'},
#  1047: {'title': 'Web Developer', 'location': 'Los Angeles'},
#  1050: {'title': 'Sales OR Business Growth Executive',
#   'location': 'Los Angeles'},
#  1060: {'title': 'Devops Engineer | Immediate Joiner',
#   'location': 'Los Angeles'},
#  1063: {'title': 'Critical Care - Sr Resident/attending Consultant-Ohio / New York',
#   'location': 'Los Angeles'},
#  1073: {'title': 'MANAGER - OPERATIONS', 'location': 'Los Angeles'},
#  1076: {'title': 'Chartered Accountant', 'location': 'Los Angeles'},
#  1086: {'title': 'Urgent Opening For Front End Developer @ Perennial Systems, New Jersey',
#   'location': 'Los Angeles'},
#  1089: {'title': 'Sales Executive', 'location': 'Los Angeles'},
#  1099: {'title': 'Head - Company Secretary', 'location': 'Los Angeles'},
#  1102: {'title': 'Jr Software Tester', 'location': 'Los Angeles'},
#  1112: {'title': 'Product Support Specialist', 'location': 'Los Angeles'},
#  1115: {'title': 'Merchandiser-hard Goods- Buying House-30k-Ohio',
#   'location': 'Los Angeles'},
#  1125: {'title': 'Top Branded intl bpo Hiring for Inbound Voice Process',
#   'location': 'Los Angeles'},
#  1128: {'title': 'Team Leader For Customer Care Center',
#   'location': 'Los Angeles'},
#  1138: {'title': 'PHP Developer - Xml/api/mvc/codeigniter',
#   'location': 'Los Angeles'},
#  1141: {'title': 'Microsoft Excel Analyst', 'location': 'Los Angeles'},
#  5003: {'title': 'Data Scientist', 'location': 'Los Angeles'},
#  5013: {'title': 'Now Recruiting. UK /US inbound voice Support',
#   'location': 'Los Angeles'},
#  5019: {'title': 'Relationship Manager - B2C', 'location': 'Los Angeles'},
#  5029: {'title': "CA Fresher(walkin on Wednesday,22nd May'19)",
#   'location': 'Los Angeles'},
#  5035: {'title': 'IOS Developer-nariman Point Arizona',
#   'location': 'Los Angeles'},
#  5045: {'title': 'BDM', 'location': 'Los Angeles'},
#  5051: {'title': 'Senior Software Engineer', 'location': 'Los Angeles'},
#  5061: {'title': 'Senior Manager - Marketing - Luxury',
#   'location': 'Los Angeles'},
#  5067: {'title': 'Urgent Vacancy For Fresher/exp For Wipro Ltd!(excellent English Comms)',
#   'location': 'Los Angeles'},
#  5077: {'title': 'Assistant Manager - Business Development',
#   'location': 'Los Angeles'},
#  5083: {'title': 'Urgent Hiring Area Branch Manager I.C @ Bangalore in a Leading MNC',
#   'location': 'Los Angeles'},
#  5093: {'title': 'Business Analyst', 'location': 'Los Angeles'},
#  5099: {'title': 'Excellent Opening for Threat Intelligence Professional.',
#   'location': 'Los Angeles'},
#  5109: {'title': 'IT Recruiter', 'location': 'Los Angeles'},
#  5115: {'title': 'Finance Manager CA for Real Estate Company on MG Road Florida',
#   'location': 'Los Angeles'},
#  5125: {'title': 'Residential Leasing Manager Florida',
#   'location': 'Los Angeles'},
#  5131: {'title': 'Financial Advisor/relationship Manager - HNI Segment',
#   'location': 'Los Angeles'},
#  5141: {'title': 'Business Development Coordinator',
#   'location': 'Los Angeles'},
#  5147: {'title': 'Data Engineer', 'location': 'Los Angeles'},
#  5157: {'title': 'Asst Manager -purchase @ Ohio', 'location': 'Los Angeles'},
#  5163: {'title': 'MCA Internship in', 'location': 'Los Angeles'},
#  5173: {'title': 'Sr. Data Analyst- Tableau, Sql Analyst',
#   'location': 'Los Angeles'},
#  5179: {'title': 'Associate Engineer Development', 'location': 'Los Angeles'},
#  5189: {'title': 'Medical Coder', 'location': 'Los Angeles'},
#  5195: {'title': 'Fire Fighting Draughtsman', 'location': 'Los Angeles'},
#  5205: {'title': 'Tele Caller (apprenticeship)', 'location': 'Los Angeles'},
#  5211: {'title': 'Staff Software Engineer – Development',
#   'location': 'Los Angeles'},
#  5221: {'title': 'SAN Adminstrator || New York Location || Immediate Start',
#   'location': 'Los Angeles'},
#  5227: {'title': 'Marketing Executive', 'location': 'Los Angeles'},
#  5237: {'title': 'Recovery Executive', 'location': 'Los Angeles'},
#  5243: {'title': 'SAP BO Dashboard Architect', 'location': 'Los Angeles'},
#  5253: {'title': 'Asst. Regional Sales Head - Bancassurance & Alliances - Life Insurance',
#   'location': 'Los Angeles'},
#  5259: {'title': 'Report writing and Financial Modelling- Equity Research',
#   'location': 'Los Angeles'},
#  5269: {'title': 'Performance Testing', 'location': 'Los Angeles'},
#  5275: {'title': 'HR & Admin Executive', 'location': 'Los Angeles'},
#  5285: {'title': 'Accounts Executive (Should be expert in Quick Books)',
#   'location': 'Los Angeles'},
#  5291: {'title': 'Assistant Manager/ Executive/ Sr. Officer - Quality Control - Arizona',
#   'location': 'Los Angeles'},
#  5301: {'title': 'Opening for Desktop Support Engineer, New Jersey',
#   'location': 'Los Angeles'},
#  5307: {'title': 'QA Engineer (selenium & Appium)', 'location': 'Los Angeles'},
#  5317: {'title': 'MIS Executive', 'location': 'Los Angeles'},
#  5323: {'title': 'Sr Manager/agm Treasury/finance,manufacturing,nariman Point.',
#   'location': 'Los Angeles'},
#  5333: {'title': 'Manager - Digital Sales', 'location': 'Los Angeles'},
#  5339: {'title': 'OT Technician', 'location': 'Los Angeles'},
#  5349: {'title': 'Render Compute Lead Developer', 'location': 'Los Angeles'},
#  5355: {'title': 'For the post of Sales Head - Switchgear LV - Utilities & Tenders.',
#   'location': 'Los Angeles'},
#  5365: {'title': 'Civil Site Engineer', 'location': 'Los Angeles'},
#  5371: {'title': 'Automation Engineer - Ems/nms Products',
#   'location': 'Los Angeles'},
#  5381: {'title': 'Sr Manager- Finance & Accounting',
#   'location': 'Los Angeles'},
#  5387: {'title': 'Hiring :: Pega Se-ii Developers :: Quest Diagnostics :: Hyderabad',
#   'location': 'Los Angeles'},
#  5397: {'title': 'Asp.net - Team Lead', 'location': 'Los Angeles'},
#  5403: {'title': 'Fintech Corporate Banking Operations Processes Support Back Mid Office',
#   'location': 'Los Angeles'},
#  5413: {'title': 'Position: Assistant Manager / Deputy Manager Home LoanLocation:Ahme',
#   'location': 'Los Angeles'},
#  5419: {'title': 'Site Engineer', 'location': 'Los Angeles'},
#  5429: {'title': 'Director of Cloud & Global Systems Integrator Partnerships',
#   'location': 'Los Angeles'},
#  5435: {'title': 'Immediate Multiple Php/laravel Developer Required',
#   'location': 'Los Angeles'},
#  5445: {'title': 'Walk - In for Accounts Executive',
#   'location': 'Los Angeles'},
#  5451: {'title': 'Immediate Job Opening for Domestic IT Recruiter for Business Arts Indi',
#   'location': 'Los Angeles'},
#  5461: {'title': 'Divisional Head- Arizona', 'location': 'Los Angeles'},
#  5467: {'title': 'Bhumi | Careers: Curriculum Manager (IGNITE)',
#   'location': 'Los Angeles'},
#  5477: {'title': 'Structural Engineer (M.E Structures)',
#   'location': 'Los Angeles'},
#  5483: {'title': 'Technical Manager - .Net', 'location': 'Los Angeles'},
#  5493: {'title': 'LTE- Physical Layer 1- DSP Developer',
#   'location': 'Los Angeles'},
#  5499: {'title': 'Area Manager with Top Fashion Retail- New Jersey',
#   'location': 'Los Angeles'},
#  5509: {'title': 'Six Sigma Consultant ( Software)',
#   'location': 'Los Angeles'},
#  5515: {'title': 'SocialAgri Business Specialist', 'location': 'Los Angeles'},
#  5525: {'title': 'Manager Collections', 'location': 'Los Angeles'},
#  5531: {'title': 'NS_Dot with WPF', 'location': 'Los Angeles'},
#  5541: {'title': 'Head - IT Product Management/ Project Management',
#   'location': 'Los Angeles'},
#  5547: {'title': 'Marketing Executive', 'location': 'Los Angeles'},
#  5557: {'title': 'IOS Resource', 'location': 'Los Angeles'},
#  5563: {'title': 'Telemarketing Customer Service Executive Corporate Sales',
#   'location': 'Los Angeles'},
#  5573: {'title': 'Urgent Requirement _ Purchase Executive',
#   'location': 'Los Angeles'},
#  5579: {'title': 'Urgent Hiring Relationship Manager - Mortgage loan',
#   'location': 'Los Angeles'},
#  5589: {'title': 'Application Support Manager', 'location': 'Los Angeles'},
#  5595: {'title': 'Regional Service Coordinator Diploma in Refrigeration',
#   'location': 'Los Angeles'},
#  5605: {'title': 'Supervisor-Housekeeping', 'location': 'Los Angeles'},
#  5611: {'title': 'FINANCE EXECUTIVE', 'location': 'Los Angeles'},
#  5621: {'title': 'Python Sr developer', 'location': 'Los Angeles'},
#  5627: {'title': 'Recruiting Candidate For Inbound Voice Tech Support Inbound Tech Sales',
#   'location': 'Los Angeles'},
#  5637: {'title': 'Manager Corporate HR>> Female Candidates Only',
#   'location': 'Los Angeles'},
#  5643: {'title': 'Vice President Sales ( Industrial Automation Products ) : New Jersey',
#   'location': 'Los Angeles'},
#  5653: {'title': 'Manager HR', 'location': 'Los Angeles'},
#  5659: {'title': 'Experienced Game Artist Walkin || Chennai (1 - 5 y)',
#   'location': 'Los Angeles'},
#  5669: {'title': 'Network Billing Analyst', 'location': 'Los Angeles'},
#  5675: {'title': 'Cluster Manager - Credit Operations/Senior Cluster Manager',
#   'location': 'Los Angeles'},
#  5685: {'title': 'BTN Engineer', 'location': 'Los Angeles'},
#  5691: {'title': 'PHP Developer', 'location': 'Los Angeles'},
#  5701: {'title': 'Technical Person (Electronics)', 'location': 'Los Angeles'},
#  5707: {'title': 'MS Dynamics Axapta', 'location': 'Los Angeles'},
#  5717: {'title': 'SAP ABAP GTS Consultant New Jersey, Hyderabad, Bangalore,New York',
#   'location': 'Los Angeles'},
#  5723: {'title': 'Enterprise Network Operations', 'location': 'Los Angeles'},
#  5733: {'title': 'Urgent Opening For Content Writer',
#   'location': 'Los Angeles'},
#  5739: {'title': 'Hiring Freshers||business Development Executives & Managers',
#   'location': 'Los Angeles'},
#  5749: {'title': 'Sales Head', 'location': 'Los Angeles'},
#  5755: {'title': 'Mega Walkin For Tech Support with Good Package!!! Meet HR VEER',
#   'location': 'Los Angeles'},
#  5765: {'title': 'Fleet of Modern Oil/Chemical Tankers',
#   'location': 'Los Angeles'},
#  5771: {'title': 'Manager - Corporate Sales - Employee Benefits Solutions',
#   'location': 'Los Angeles'},
#  5781: {'title': 'Sr Analyst - Financial Planning & Analysis',
#   'location': 'Los Angeles'},
#  5787: {'title': 'Opening For Web Designer For Andheri Location',
#   'location': 'Los Angeles'},
#  5797: {'title': 'Professional Details', 'location': 'Los Angeles'},
#  5803: {'title': 'Dot Net Developer', 'location': 'Los Angeles'},
#  5813: {'title': 'Web Developer', 'location': 'Los Angeles'},
#  5819: {'title': 'Urgent Hiring B.tech & M.b.a - HR IT Recruiter- Part Time - Female',
#   'location': 'Los Angeles'},
#  5829: {'title': 'Desktop Support', 'location': 'Los Angeles'},
#  5835: {'title': 'Sr. Executive HR (trainings)', 'location': 'Los Angeles'},
#  5845: {'title': 'Research Consultant', 'location': 'Los Angeles'},
#  5851: {'title': 'User Interface Design and Development',
#   'location': 'Los Angeles'},
#  5861: {'title': 'Procurement Engineer/ Officer', 'location': 'Los Angeles'},
#  5867: {'title': 'Oracle Trainer', 'location': 'Los Angeles'},
#  5877: {'title': 'Sr. Engineer Creo', 'location': 'Los Angeles'},
#  5883: {'title': 'Marketing Executive', 'location': 'Los Angeles'},
#  5893: {'title': 'Head HR CRD', 'location': 'Los Angeles'},
#  5899: {'title': 'Business Development Manager', 'location': 'Los Angeles'},
#  5909: {'title': 'Markets Client Strategy', 'location': 'Los Angeles'},
#  5915: {'title': 'Senior Software Engineer', 'location': 'Los Angeles'},
#  5925: {'title': 'Sr Engineer Frame Design Engn', 'location': 'Los Angeles'},
#  5931: {'title': 'Javascript Developer', 'location': 'Los Angeles'},
#  5941: {'title': 'Pega Lead Consultant - PRPC - Cssa/ CLSA Certified',
#   'location': 'Los Angeles'},
#  5947: {'title': 'Hiring Assistant Manager Sales-4+exp in Logistic',
#   'location': 'Los Angeles'},
#  5957: {'title': 'Amazon Captive Hiring For Chat/ Voice Profiles - Salary up To 25k+inc.',
#   'location': 'Los Angeles'},
#  5963: {'title': 'Customer Care BPO Executive', 'location': 'Los Angeles'},
#  5973: {'title': 'Dundas Developers', 'location': 'Los Angeles'},
#  5979: {'title': 'Software Analyst - Java/selenium Freshers',
#   'location': 'Los Angeles'},
#  5989: {'title': 'Sr. Technical Writer (contractual Job : 6 Months)',
#   'location': 'Los Angeles'},
#  5995: {'title': 'PPC Executive', 'location': 'Los Angeles'},
#  6005: {'title': 'PHP Developer for MNC 5 Day Working MNC.',
#   'location': 'Los Angeles'},
#  6011: {'title': 'EHS Officer/environment at Taloja and Badlapur Location',
#   'location': 'Los Angeles'},
#  6021: {'title': 'Field Sales Executive_Powai', 'location': 'Los Angeles'},
#  6027: {'title': 'Firmware Engineer', 'location': 'Los Angeles'},
#  6037: {'title': 'Associate - Controls Room Business Analyst & Data Management',
#   'location': 'Los Angeles'},
#  6043: {'title': 'Senior Salesforce.com Administrator',
#   'location': 'Los Angeles'},
#  6053: {'title': 'Service Engineer', 'location': 'Los Angeles'},
#  6059: {'title': 'Technical Executive / Technical Sales Executive',
#   'location': 'Los Angeles'},
#  6069: {'title': 'Graphic Designer', 'location': 'Los Angeles'},
#  6075: {'title': 'Sales Executive Jewellery / Retail Industry',
#   'location': 'Los Angeles'},
#  6085: {'title': 'Software Positions in', 'location': 'Los Angeles'},
#  6091: {'title': 'Accounts Executive', 'location': 'Los Angeles'},
#  6101: {'title': 'Openings-.net Developer(c#,.net,wpf,unit Testing) New Jersey',
#   'location': 'Los Angeles'},
#  6107: {'title': 'Urgent Hiring for Business Communication (female Candidates Only)',
#   'location': 'Los Angeles'},
#  6117: {'title': 'Engineer Security Management', 'location': 'Los Angeles'},
#  6123: {'title': 'JAVA DEVELOPER', 'location': 'Los Angeles'},
#  6133: {'title': 'Openings with Ness Technologies For Front End Developer',
#   'location': 'Los Angeles'},
#  6139: {'title': 'Iphone Developer in Chandigarh', 'location': 'Los Angeles'},
#  6149: {'title': 'Reservation & Ticketing [for a Reputed Airline',
#   'location': 'Los Angeles'},
#  6155: {'title': 'marketing Associate', 'location': 'Los Angeles'},
#  6165: {'title': 'Assistant Manager Sales', 'location': 'Los Angeles'},
#  6171: {'title': 'Urgent Opening for "ICT Manager for Data Center',
#   'location': 'Los Angeles'},
#  6181: {'title': 'Senior Software Engineer', 'location': 'Los Angeles'},
#  6187: {'title': 'Marketing Digital Marketing', 'location': 'Los Angeles'},
#  6197: {'title': 'Physiotherapist', 'location': 'Los Angeles'},
#  6203: {'title': 'IOS Mobile Developer - Objective C/swift',
#   'location': 'Los Angeles'},
#  6213: {'title': 'Store Supervisor - Retail Sales - Sportswear',
#   'location': 'Los Angeles'},
#  6219: {'title': 'Android Lead', 'location': 'Los Angeles'},
#  6229: {'title': 'Engineer, Senior Software Integration',
#   'location': 'Los Angeles'},
#  6235: {'title': 'Python Lead', 'location': 'Los Angeles'},
#  6245: {'title': 'Wordpress Developer', 'location': 'Los Angeles'},
#  6251: {'title': 'Project Co-Ordinator', 'location': 'Los Angeles'},
#  6261: {'title': 'Business Analyst', 'location': 'Los Angeles'},
#  6267: {'title': 'Job Opening in BPO for International Inbound Calling profile/US Shift',
#   'location': 'Los Angeles'},
#  6277: {'title': 'Senior Accounts Executive/ Assistant Manager (accounts)',
#   'location': 'Los Angeles'},
#  6283: {'title': 'Technical Support Associate', 'location': 'Los Angeles'},
#  6293: {'title': 'Accounts Executive at Arizona', 'location': 'Los Angeles'},
#  6299: {'title': 'Android Apps Development Engineer',
#   'location': 'Los Angeles'},
#  6309: {'title': 'SEO Executive', 'location': 'Los Angeles'},
#  6315: {'title': 'Business Analysis - Life Insurance',
#   'location': 'Los Angeles'},
#  6325: {'title': 'Lucrative Opportunity For EPC Recruiters - Bangalore',
#   'location': 'Los Angeles'},
#  6331: {'title': 'Business Development Manager', 'location': 'Los Angeles'},
#  6341: {'title': 'Offshore - Instrumentation Engineer',
#   'location': 'Los Angeles'},
#  6347: {'title': 'Wintel System Administration', 'location': 'Los Angeles'},
#  6357: {'title': 'sap transportation', 'location': 'Los Angeles'},
#  6363: {'title': 'Business Developer - Female', 'location': 'Los Angeles'},
#  6373: {'title': 'iOS Developer', 'location': 'Los Angeles'},
#  6379: {'title': 'Facilities Management', 'location': 'Los Angeles'},
#  6389: {'title': 'Inside Sales Executive', 'location': 'Los Angeles'},
#  6395: {'title': 'Senior Software Engineer', 'location': 'Los Angeles'},
#  6405: {'title': 'Communications Executive', 'location': 'Los Angeles'},
#  6411: {'title': 'Power Business Intelligence (BI) Developer,New York',
#   'location': 'Los Angeles'},
#  6421: {'title': 'Asp.net Developer', 'location': 'Los Angeles'},
#  6427: {'title': 'Expansion Manager', 'location': 'Los Angeles'},
#  6437: {'title': 'Relationship Manager', 'location': 'Los Angeles'},
#  6443: {'title': 'A TYRE Brand Industry Hiring Sales Person (tyre Industry)',
#   'location': 'Los Angeles'},
#  6453: {'title': 'Java Developer', 'location': 'Los Angeles'},
#  6459: {'title': 'QA Analyst', 'location': 'Los Angeles'},
#  6469: {'title': 'Software Development Engineer- 2 (Fullstack)',
#   'location': 'Los Angeles'},
#  6475: {'title': 'Health Advice Officer', 'location': 'Los Angeles'},
#  6485: {'title': 'Durability Professional', 'location': 'Los Angeles'},
#  6491: {'title': 'Enterprise Apps Manager', 'location': 'Los Angeles'},
#  6501: {'title': 'Data Architect', 'location': 'Los Angeles'},
#  6507: {'title': 'Team Leader - Digital Marketing', 'location': 'Los Angeles'},
#  6517: {'title': 'AM/ Manager - Transaction Advisory / FDD Role',
#   'location': 'Los Angeles'},
#  6523: {'title': 'Sales / Business Development', 'location': 'Los Angeles'},
#  6533: {'title': 'Executive Admin - CRG', 'location': 'Los Angeles'},
#  6539: {'title': 'PHP Developer / SE / SSE', 'location': 'Los Angeles'},
#  6549: {'title': 'Site Engineer', 'location': 'Los Angeles'},
#  6555: {'title': 'Marketing Executives', 'location': 'Los Angeles'},
#  6565: {'title': 'Graphic Designer with Excellent Skills',
#   'location': 'Los Angeles'},
#  6571: {'title': 'Android Developer', 'location': 'Los Angeles'},
#  6581: {'title': 'Master Data Management (talend/kalido/reltio/others)',
#   'location': 'Los Angeles'},
#  6587: {'title': 'Business Analyst - Digital Transformation - New Jersey',
#   'location': 'Los Angeles'},
#  6597: {'title': 'Fresher- Diploma in Paint Technology',
#   'location': 'Los Angeles'},
#  6603: {'title': 'Service Engineer', 'location': 'Los Angeles'},
#  6613: {'title': 'Key Developer Sales/super Strategic Accounts',
#   'location': 'Los Angeles'},
#  6619: {'title': 'Build and Release Engineer', 'location': 'Los Angeles'},
#  6629: {'title': 'EDI Specialist', 'location': 'Los Angeles'},
#  6635: {'title': 'Delivery Manager', 'location': 'Los Angeles'},
#  6645: {'title': 'Process Lead, Client Accounting', 'location': 'Los Angeles'},
#  6651: {'title': 'Web Designer', 'location': 'Los Angeles'},
#  6661: {'title': 'Senior Implementation/Project Engineer',
#   'location': 'Los Angeles'},
#  6667: {'title': 'Walk-in Drive For Branch Head- Florida&Ohio (11am-4pm)',
#   'location': 'Los Angeles'},
#  6677: {'title': 'Analyst, Transaction Monitoring - NCB',
#   'location': 'Los Angeles'},
#  6683: {'title': 'Engineering Manager', 'location': 'Los Angeles'},
#  6693: {'title': 'Channel Lead - Modern Trade Sales - FMCG - Iim/iit',
#   'location': 'Los Angeles'},
#  6699: {'title': 'Required Store Incharg in VMT Ghaziabad',
#   'location': 'Los Angeles'},
#  6709: {'title': 'Assistant Vice President - Product & Strategy - Real Estate',
#   'location': 'Los Angeles'},
#  6715: {'title': 'Oral Liquid Chemist', 'location': 'Los Angeles'},
#  6725: {'title': 'Business Development Manager For Facilities Services',
#   'location': 'Los Angeles'},
#  6731: {'title': 'If you believe you are a Tech Call Closer Then Join Adeeba BPO.',
#   'location': 'Los Angeles'},
#  6741: {'title': 'Consultant - Enterprise Security Consulting and SI',
#   'location': 'Los Angeles'},
#  6747: {'title': 'Senior Test Engineer', 'location': 'Los Angeles'},
#  6757: {'title': 'Tech Lead MERN Stack Developer', 'location': 'Los Angeles'},
#  6763: {'title': 'Walk Drive For Undergraduate Freshers',
#   'location': 'Los Angeles'},
#  6773: {'title': 'Walk Ins For Account Executive - Corporate Office - Thane',
#   'location': 'Los Angeles'},
#  6779: {'title': 'sr hr executive generalist', 'location': 'Los Angeles'},
#  6789: {'title': 'Sales Executive/ Manager - UPS', 'location': 'Los Angeles'},
#  6795: {'title': 'Caller-Inbound Tech process', 'location': 'Los Angeles'},
#  6805: {'title': 'Quality Analyst + Ruby', 'location': 'Los Angeles'},
#  6811: {'title': 'Inbound Process', 'location': 'Los Angeles'},
#  6821: {'title': 'Principal Consultant', 'location': 'Los Angeles'},
#  6827: {'title': 'Associate Hiring, B Tech Fresher, Fresher Trainee, Fresher Graduate',
#   'location': 'Los Angeles'},
#  6837: {'title': 'Head of Cloud Operations', 'location': 'Los Angeles'},
#  6843: {'title': 'Billing Incharge', 'location': 'Los Angeles'},
#  6853: {'title': 'SAP Recruiter For Hyderabad Location',
#   'location': 'Los Angeles'},
#  6859: {'title': 'Mechanical Engineering Jobs in New York - Design Engineer',
#   'location': 'Los Angeles'},
#  6869: {'title': 'Customer Service Associate', 'location': 'Los Angeles'},
#  6875: {'title': 'Quality Assistant', 'location': 'Los Angeles'},
#  6885: {'title': 'Risk Analyst - CAT Modeling - Insurance',
#   'location': 'Los Angeles'},
#  6891: {'title': 'Hiring FOR International (english) Outbound CALL Center Morning Shift',
#   'location': 'Los Angeles'},
#  6901: {'title': 'Job: JD of Hardware Engineer – hamson hr',
#   'location': 'Los Angeles'},
#  6907: {'title': 'Consultant', 'location': 'Los Angeles'},
#  6917: {'title': 'Digital Marketing Manager', 'location': 'Los Angeles'},
#  6923: {'title': 'SAP Material Maintainence', 'location': 'Los Angeles'},
#  6933: {'title': 'Environmental Engineering- Associate Professor',
#   'location': 'Los Angeles'},
#  6939: {'title': 'Staff Nurse - OT', 'location': 'Los Angeles'},
#  6949: {'title': 'Opening for Technical Team Lead - Charni Road- Mon-fri',
#   'location': 'Los Angeles'},
#  6955: {'title': 'Manager / Senior Manager', 'location': 'Los Angeles'},
#  6965: {'title': 'Software Engineering Team Lead, Java',
#   'location': 'Los Angeles'},
#  6971: {'title': 'Client Servicing Head - For Advertising Agency',
#   'location': 'Los Angeles'},
#  6981: {'title': 'Senior Data Scientist', 'location': 'Los Angeles'},
#  6987: {'title': 'Urgent Vacancy for Game Artist', 'location': 'Los Angeles'},
#  6997: {'title': 'Java Trainer', 'location': 'Los Angeles'},
#  7003: {'title': 'Branch Manager -stock Broking- Ahmedabad',
#   'location': 'Los Angeles'},
#  7013: {'title': 'Predictive Modeling & Optimisation Lead - Enterprise Tech',
#   'location': 'Los Angeles'},
#  7019: {'title': 'Power Bi Architect -New York,bangalore Location',
#   'location': 'Los Angeles'},
#  7029: {'title': 'Hiring for Microsoft', 'location': 'Los Angeles'},
#  7035: {'title': 'AWS Architect', 'location': 'Los Angeles'},
#  7045: {'title': 'Bulk Hiring For USA Inbound/Outbound Process',
#   'location': 'Los Angeles'},
#  7051: {'title': 'Opening for EXP Inbound Tech Callers in Tech Support/Sales-US Shift',
#   'location': 'Los Angeles'},
#  7061: {'title': 'ASSISTANT / DEPUTY MANAGER (OPERATIONS)',
#   'location': 'Los Angeles'},
#  7067: {'title': 'Design Assistant', 'location': 'Los Angeles'},
#  7077: {'title': 'NRI Banking (manager/ Sr Manager/ AVP) Leading Bank Arizona',
#   'location': 'Los Angeles'},
#  7083: {'title': 'SAP FI S / 4 HANA Accounting', 'location': 'Los Angeles'},
#  7093: {'title': 'Manager Industrial Engineer/production Engineer',
#   'location': 'Los Angeles'},
#  7099: {'title': 'Sales Manager - Direct : Bangalore',
#   'location': 'Los Angeles'},
#  7109: {'title': 'Senior Software Engg - Systems', 'location': 'Los Angeles'},
#  7115: {'title': 'Sr Manager Compliance', 'location': 'Los Angeles'},
#  7125: {'title': 'Hybris Developer', 'location': 'Los Angeles'},
#  7131: {'title': 'Assistant Business Manager', 'location': 'Los Angeles'},
#  7141: {'title': 'Fashion Consultant-female', 'location': 'Los Angeles'},
#  7147: {'title': 'Graphic Designer', 'location': 'Los Angeles'},
#  7157: {'title': 'Open Position For HR Operations ( Experience) - Manyata Tech Park',
#   'location': 'Los Angeles'},
#  7163: {'title': 'Business Development Manager', 'location': 'Los Angeles'},
#  7173: {'title': 'Software Engineer', 'location': 'Los Angeles'},
#  7179: {'title': 'Head - Category Demand & Supply Planning',
#   'location': 'Los Angeles'},
#  7189: {'title': 'Medical Writer', 'location': 'Los Angeles'},
#  7195: {'title': 'Graphics Designer', 'location': 'Los Angeles'},
#  7205: {'title': 'Hiring for Oracle ADF with UCM Experience@ Hyderabad',
#   'location': 'Los Angeles'},
#  7211: {'title': 'Jr. Data Scientist', 'location': 'Los Angeles'},
#  7221: {'title': 'Management Information Systems- Associate Professor',
#   'location': 'Los Angeles'},
#  7227: {'title': 'Salesforce Developer', 'location': 'Los Angeles'},
#  7237: {'title': 'Senior Implementation Lead', 'location': 'Los Angeles'},
#  7243: {'title': 'Software Engineer', 'location': 'Los Angeles'},
#  7253: {'title': 'Project Manager', 'location': 'Los Angeles'},
#  7259: {'title': 'Assistant Manager Finance', 'location': 'Los Angeles'},
#  7269: {'title': 'UK Tech Support Dialer Inbound Voice Process',
#   'location': 'Los Angeles'},
#  7275: {'title': 'Team Leader Operations (inbound) - Hindi',
#   'location': 'Los Angeles'},
#  7285: {'title': 'SAP for Governance, Risk & Compliance (grc)',
#   'location': 'Los Angeles'},
#  7291: {'title': 'Corporate Liaison', 'location': 'Los Angeles'},
#  7301: {'title': 'Hiring for Bpo', 'location': 'Los Angeles'},
#  7307: {'title': 'Marketing- Assistant Professor', 'location': 'Los Angeles'},
#  7317: {'title': 'MIS - Foreign Exchange', 'location': 'Los Angeles'},
#  7323: {'title': 'Massive Hiring...!! Barclays !! EXL !! Amazon ( New York)- Call Swati',
#   'location': 'Los Angeles'},
#  7333: {'title': 'SAP ABAP Consultant - Sd/mm/ FI Modules',
#   'location': 'Los Angeles'},
#  7339: {'title': 'ECom Production Support Engineer',
#   'location': 'Los Angeles'},
#  7349: {'title': 'Product Development Exec.', 'location': 'Los Angeles'},
#  7355: {'title': 'Technical Sales Representative', 'location': 'Los Angeles'},
#  7365: {'title': 'Regional Medical Advisor Jobs with Pharmaceutical MNC',
#   'location': 'Los Angeles'},
#  7371: {'title': 'Oracle Apps Technical with OAF', 'location': 'Los Angeles'},
#  7381: {'title': 'Senior Expert Web Engineering', 'location': 'Los Angeles'},
#  7387: {'title': 'Hiring for Oracle Cloud HCM Functional & Technical Consultant',
#   'location': 'Los Angeles'},
#  7397: {'title': 'Business Development Executives/Sales Executives/Management',
#   'location': 'Los Angeles'},
#  7403: {'title': 'Head of Admissions Consulting', 'location': 'Los Angeles'}}

# %% [markdown]
# ### Store the results in an excel file

# %% [markdown]
# Call the API for all the given technologies above and write the results in an excel spreadsheet.

# %% [markdown]
# If you do not know how create excel file using python, double click here for **hints**.
#
# <!--
#
# from openpyxl import Workbook        # import Workbook class from module openpyxl
# wb=Workbook()                        # create a workbook object
# ws=wb.active                         # use the active worksheet
# ws.append(['Country','Continent'])   # add a row with two columns 'Country' and 'Continent'
# ws.append(['Eygpt','Africa'])        # add a row with two columns 'Egypt' and 'Africa'
# ws.append(['India','Asia'])          # add another row
# ws.append(['France','Europe'])       # add another row
# wb.save("countries.xlsx")            # save the workbook into a file called countries.xlsx
#
#
# -->

# %% [markdown]
# Create a python list of all locations for which you need to find the number of jobs postings.

# %%
#your code goes here

# %% [markdown]
# Import libraries required to create excel spreadsheet

# %%
# your code goes here

# %% [markdown]
# Create a workbook and select the active worksheet

# %%
# your code goes here

# %% [markdown]
# Find the number of jobs postings for each of the location in the above list.
# Write the Location name and the number of jobs postings into the excel spreadsheet.

# %%
#your code goes here

# %% [markdown]
# Save into an excel spreadsheet named 'job-postings.xlsx'.

# %%
#your code goes here

# %% [markdown]
# #### In the similar way, you can try for below given technologies and results  can be stored in an excel sheet.

# %% [markdown]
# Collect the number of job postings for the following languages using the API:
#
# *   C
# *   C#
# *   C++
# *   Java
# *   JavaScript
# *   Python
# *   Scala
# *   Oracle
# *   SQL Server
# *   MySQL Server
# *   PostgreSQL
# *   MongoDB

# %%
# your code goes here

# %% [markdown]
# ## Author

# %% [markdown]
# Ayushi Jain

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja
#
# Lakshmi Holla
#
# Malika

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2022-01-19        | 0.3     | Lakshmi Holla        | Added changes in the markdown      |
# | 2021-06-25        | 0.2     | Malika            | Updated GitHub job json link       |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2022 IBM Corporation. All rights reserved.
